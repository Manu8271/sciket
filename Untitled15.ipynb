# %% [markdown]
# <a href="https://colab.research.google.com/github/Manu8271/sciket/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
print(f"last updated: {datetime.datetime.now()}")
print(f"sklearn verion: {sklearn.__version__}")
# Out:
# last updated: 2023-12-08 04:15:53.649584
# sklearn verion: 1.2.2

# %%
url = 'https://github.com/mrdbourke/zero-to-mastery-ml/raw/master/data/heart-disease.csv'
heart_disease = pd.read_csv(url)
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...
